# %%
import pandas as pd
import unicodecsv
import numpy as np 
from pandas import Series,DataFrame

# %%
train_data = 'C:\\Shesha\\DS\\Practise\\Titanic\\train.csv'
titanic_df = pd.read_csv(train_data)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# this will tell us about how the data is inside the Data frames
titanic_df.info()
titanic_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
malfae =[] 
plt.figure()

titanic_df_males = titanic_df[titanic_df['Sex'] == 'male']


titanic_df_females = titanic_df[titanic_df['Sex'] == 'female']

titanic_df['Sex'].loc[titanic_df['Sex'] == 'male'] = 1
titanic_df['Sex'].loc[titanic_df['Sex'] == 'female'] = 0

titanic_df['Sex'].plot.hist()
pclass_xt = pd.crosstab(titanic_df['Pclass'], titanic_df['Survived'])
pclass_xt.plot(kind='bar')



pclass_xt = pd.crosstab(titanic_df['Sex'], titanic_df['Survived'])
pclass_xt.plot(kind='bar')



#sns.countplot('Sex',data=titanic_df)
# Out:
# C:\Users\Viki\Anaconda3\lib\site-packages\pandas\core\indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df_males.head()
pclass_xt = pd.crosstab(titanic_df_males['Pclass'], titanic_df['Survived'])
pclass_xt.plot(kind='bar')

pclass_xt = pd.crosstab(titanic_df_females['Pclass'], titanic_df['Survived'])
pclass_xt.plot(kind='bar')

# %%
sns.countplot('Sex',data=titanic_df,hue='Pclass')

# %%
sns.countplot('Embarked',data=titanic_df,hue='Pclass')

# %%
titanic_df['Alone'] = titanic_df.SibSp +  titanic_df.Parch

# %%
titanic_df['Alone'].loc[titanic_df['Alone'] > 0] = 0 ## Family
titanic_df['Alone'].loc[titanic_df['Alone'] == 0] = 1 ## Single
# Out:
# C:\Users\Viki\Anaconda3\lib\site-packages\pandas\core\indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sns.countplot('Alone',data=titanic_df)

# %%
sns.countplot('Survived',data=titanic_df,palette='Set1')

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=titanic_df)

# %%
#Age vs Survivals
sns.lmplot('Age','Survived',data=titanic_df)

# %%
# Get the unique values of Embarked
embarked_locs = titanic_df['Embarked'].unique()

embarked_locs_mapping = dict(zip(embarked_locs, 
                                 range(0, len(embarked_locs) + 1)))
embarked_locs_mapping
# Out:
# {'Q': 2, 'C': 1, 'S': 0, nan: 3}

# %%
titanic_df['Embarked_Val'] = titanic_df['Embarked'] \
                               .map(embarked_locs_mapping) \
                               .astype(int)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0      1      0
# 2                             Heikkinen, Miss. Laina   0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0      1      0
# 4                           Allen, Mr. William Henry   1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Alone  Embarked_Val
# 0         A/5 21171   7.2500   NaN        S      1             0
# 1          PC 17599  71.2833   C85        C      1             1
# 2  STON/O2. 3101282   7.9250   NaN        S      0             0
# ...

# %%
titanic_df = titanic_df.drop(['Name', 'Ticket', 'Cabin', 'Embarked'], 
                         axis=1)

# %%
titanic_df['AgeFill'] = titanic_df['Age']

# Populate AgeFill
titanic_df['AgeFill'] = titanic_df['AgeFill'] \
                        .groupby([titanic_df['Sex'], titanic_df['Pclass']]) \
                        .apply(lambda x: x.fillna(x.median()))

# %%
titanic_df.head()
len(titanic_df[titanic_df['AgeFill'].isnull()])
# Out:
# 0
